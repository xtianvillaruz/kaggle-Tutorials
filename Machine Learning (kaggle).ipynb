# %% [markdown]
# # Machine Learning

# %% [markdown]
# ## Level 1

# %% [markdown]
# ## Starting Your Project

# %%
import pandas as pd

# %%
melbourne_data = pd.read_csv('melb_data.csv')
melbourne_data.shape
# Out:
# (18396, 22)

# %%
melbourne_data[melbourne_data.isnull().any(axis=1)]
# Out:
#        Unnamed: 0          Suburb              Address  Rooms Type      Price  \
# 0               1      Abbotsford         85 Turner St      2    h  1480000.0
# 3               5      Abbotsford     40 Federation La      3    h   850000.0
# 5              10      Abbotsford       129 Charles St      2    h   941000.0
# 8              15      Abbotsford     217 Langridge St      3    h  1000000.0
# 9              16      Abbotsford      18a Mollison St      2    t   745000.0
# 10             17      Abbotsford   6/241 Nicholson St      1    u   300000.0
# 12             19      Abbotsford  403/609 Victoria St      2    u   542000.0
# 13             21      Abbotsford    25/84 Trenerry Cr      2    u   760000.0
# 14             22      Abbotsford    106/119 Turner St      1    u   481000.0
# 15             23      Abbotsford   411/8 Grosvenor St      2    u   700000.0
# 18             26      Abbotsford           22 Park St      4    h  1985000.0
# 19             27      Abbotsford    13/84 Trenerry Cr      1    u   500000.0
# 20             28      Abbotsford        45 William St      2    h  1172500.0
# 21             29      Abbotsford   7/20 Abbotsford St      1    u   441000.0
# 24             33      Abbotsford     250 Langridge St      2    t   847000.0
# 26             36      Abbotsford     196 Nicholson St      3    h   955000.0
# 29             40      Abbotsford   13/11 Nicholson St      3    t   900000.0
# 30             41      Abbotsford  138/56 Nicholson St      3    u  1090000.0
# 34             45      Abbotsford    65/80 Trenerry Cr      1    u   480000.0
# 35             46      Abbotsford  119/52 Nicholson St      1    u   423500.0
# 36             48      Abbotsford   5/20 Abbotsford St      1    u   426000.0
# 38             50      Abbotsford  116/56 Nicholson St      1    u   457000.0
# 40             52      Abbotsford    49/84 Trenerry Cr      2    h   700000.0
# 41             53      Abbotsford         31 Turner St      4    h  1542000.0
# 42             54      Abbotsford        17/1 Abbot St      3    t   962000.0
# 43             55      Abbotsford         166 Gipps St      3    h  1290000.0
# 49             62      Abbotsford    82/84 Trenerry Cr      2    u   970000.0
# 51             65      Abbotsford    40/80 Trenerry Cr      3    h   927000.0
# 59             74    Airport West          4/9 West Ct      2    t   420000.0
# 60             75    Airport West         1/36 York St      3    t   500000.0
# ...           ...             ...                  ...    ...  ...        ...
# 18366       23508          Toorak   21/1059 Malvern Rd      2    u   720000.0
# 18367       23509          Toorak     25/637 Orrong Rd      2    u   631000.0
# 18368       23510       Truganina         12 Arthur Cl      3    h   523000.0
# 18369       23511     Tullamarine      3/32 Banksia Gr      2    u   530000.0
# 18370       23512     Tullamarine         7 Londrew Ct      3    h   540000.0
# 18371       23513     Tullamarine       1/34 Sharps Rd      2    u   290000.0
# 18372       23514         Vermont       73 Nurlendi Rd      4    h  1263500.0
# 18373       23515   Vermont South      308 Hawthorn Rd      3    t   931000.0
# 18374       23517   Vermont South        2 Settlers Ct      4    h  1295000.0
# 18375       23518   Vermont South        9 Winswood Cl      4    h  1250000.0
# 18376       23519        Viewbank        149 Graham Rd      5    h  1316000.0
# 18377       23521        Wantirna   16 chesterfield Ct      4    h   951000.0
# 18378       23523  Wantirna South         12 Armagh Cr      4    h  1323000.0
# 18379       23524  Wantirna South        34 Fewster Dr      3    h   970000.0
# 18380       23525  Wantirna South           15 Mara Cl      4    h  1330000.0
# 18381       23526        Watsonia       2/14 Daours Ct      2    u   590000.0
# 18382       23527        Watsonia        76 Kenmare St      2    h   650000.0
# 18383       23531        Werribee         91 Latham St      4    h   540000.0
# 18384       23532        Werribee          5 Nuragi Ct      4    h   635000.0
# 18385       23534  West Footscray      1/21 Waratah St      2    t   655000.0
# 18386       23535     Westmeadows           9 Black St      3    h   582000.0
# 18387       23536     Westmeadows      81 Hillcrest Dr      4    h   720000.0
# 18388       23537   Wheelers Hill         12 Strada Cr      4    h  1245000.0
# 18389       23538    Williamstown        77 Merrett Dr      3    h  1031000.0
# 18390       23539    Williamstown          83 Power St      3    h  1170000.0
# 18391       23540    Williamstown      8/2 Thompson St      2    t   622500.0
# 18392       23541    Williamstown         96 Verdon St      4    h  2500000.0
# 18393       23544       Yallambie         17 Amaroo Wy      4    h  1100000.0
# 18394       23545      Yarraville           6 Agnes St      4    h  1285000.0
# 18395       23546      Yarraville        33 Freeman St      4    h  1050000.0
#
#       Method        SellerG        Date  Distance      ...        Bathroom  \
# 0          S         Biggin   3/12/2016       2.5      ...             1.0
# 3         PI         Biggin   4/03/2017       2.5      ...             2.0
# 5          S         Jellis   7/05/2016       2.5      ...             1.0
# 8          S         Jellis   8/10/2016       2.5      ...             NaN
# 9          S         Jellis   8/10/2016       2.5      ...             NaN
# 10         S         Biggin   8/10/2016       2.5      ...             1.0
# 12         S         Dingle   8/10/2016       2.5      ...             NaN
# 13        SP         Biggin  10/12/2016       2.5      ...             NaN
# 14        SP   Purplebricks  10/12/2016       2.5      ...             NaN
# 15        VB         Jellis  12/11/2016       2.5      ...             2.0
# 18         S         Biggin  12/11/2016       2.5      ...             NaN
# 19         S         Biggin  12/11/2016       2.5      ...             NaN
# 20         S         Biggin  13/08/2016       2.5      ...             1.0
# 21        SP           Greg  14/05/2016       2.5      ...             1.0
# 24         S         Jellis  16/07/2016       2.5      ...             NaN
# 26         S        Collins  17/09/2016       2.5      ...             1.0
# 29         S         Beller  18/03/2017       2.5      ...             2.0
# 30         S         Jellis  18/03/2017       2.5      ...             2.0
# 34         S         Biggin  19/11/2016       2.5      ...             NaN
# 35         S  hockingstuart  22/05/2016       2.5      ...             NaN
# 36        SP           Greg  22/08/2016       2.5      ...             1.0
# 38         S         Jellis  22/08/2016       2.5      ...             1.0
# 40         S         Biggin  23/04/2016       2.5      ...             NaN
# 41         S        Collins  24/09/2016       2.5      ...             3.0
# 42        SP         Jellis  25/02/2017       2.5      ...             NaN
# 43         S         Biggin  25/02/2017       2.5      ...             2.0
# 49        SP         Biggin  28/05/2016       2.5      ...             NaN
# 51         S         Biggin  30/07/2016       2.5      ...             NaN
# 59        VB          Barry   4/06/2016      13.5      ...             NaN
# 60        VB         Nelson   4/06/2016      13.5      ...             NaN
# ...      ...            ...         ...       ...      ...             ...
# 18366     VB         Beller  26/08/2017       4.1      ...             NaN
# 18367     SP         Jellis  26/08/2017       4.1      ...             1.0
# 18368      S          Barry  26/08/2017      18.4      ...             2.0
# 18369      S          Jason  26/08/2017      12.9      ...             1.0
# 18370      S          Barry  26/08/2017      12.9      ...             1.0
# 18371     VB          Barry  26/08/2017      12.9      ...             1.0
# 18372      S          Barry  26/08/2017      17.2      ...             2.0
# 18373      S         Biggin  26/08/2017      17.2      ...             2.0
# 18374     SP   Purplebricks  26/08/2017      17.2      ...             2.0
# 18375     PI         Philip  26/08/2017      17.2      ...             2.0
# 18376     SP         Nelson  26/08/2017       8.9      ...             3.0
# 18377      S            Ray  26/08/2017      14.7      ...             2.0
# 18378      S          Barry  26/08/2017      14.7      ...             2.0
# 18379      S          Barry  26/08/2017      14.7      ...             2.0
# 18380      S          Barry  26/08/2017      14.7      ...             2.0
# 18381      S      Lindellas  26/08/2017      14.5      ...             1.0
# 18382     PI       Morrison  26/08/2017      14.5      ...             1.0
# 18383     PI        Triwest  26/08/2017      14.7      ...             NaN
# 18384      S  hockingstuart  26/08/2017      14.7      ...             2.0
# 18385      S            Jas  26/08/2017       6.4      ...             2.0
# 18386      S            Red  26/08/2017      16.5      ...             2.0
# 18387     VB          Barry  26/08/2017      16.5      ...             2.0
# 18388      S          Barry  26/08/2017      16.7      ...             2.0
# 18389     SP       Williams  26/08/2017       6.8      ...             2.0
# 18390      S          Raine  26/08/2017       6.8      ...             2.0
# 18391     SP           Greg  26/08/2017       6.8      ...             2.0
# 18392     PI        Sweeney  26/08/2017       6.8      ...             1.0
# 18393      S     Buckingham  26/08/2017      12.7      ...             3.0
# 18394     SP        Village  26/08/2017       6.3      ...             1.0
# 18395     VB        Village  26/08/2017       6.3      ...             2.0
#
#        Car  Landsize  BuildingArea  YearBuilt  CouncilArea  Lattitude  \
# 0      1.0     202.0           NaN        NaN        Yarra  -37.79960
# 3      1.0      94.0           NaN        NaN        Yarra  -37.79690
# 5      0.0     181.0           NaN        NaN        Yarra  -37.80410
# 8      NaN       NaN           NaN        NaN          NaN        NaN
# 9      NaN       NaN           NaN        NaN          NaN        NaN
# 10     1.0       0.0           NaN        NaN        Yarra  -37.80080
# 12     NaN       NaN           NaN        NaN          NaN        NaN
# 13     NaN       NaN           NaN        NaN          NaN        NaN
# 14     NaN       NaN           NaN        NaN          NaN        NaN
# 15     1.0       0.0           NaN        NaN        Yarra  -37.81100
# 18     NaN       NaN           NaN        NaN          NaN  -37.80840
# 19     NaN       NaN           NaN        NaN          NaN        NaN
# 20     1.0     195.0           NaN        NaN        Yarra  -37.80840
# 21     1.0       0.0           NaN        NaN        Yarra  -37.80160
# 24     NaN       NaN           NaN        NaN          NaN        NaN
# 26     0.0     183.0           NaN        NaN        Yarra  -37.80220
# 29     2.0       0.0           NaN     2010.0        Yarra  -37.80930
# 30     2.0    4290.0          27.0        NaN        Yarra  -37.80780
# 34     NaN       NaN           NaN        NaN          NaN        NaN
# 35     NaN       NaN           NaN        NaN          NaN        NaN
# 36     1.0       0.0           NaN        NaN        Yarra  -37.80160
# 38     1.0       0.0          50.0        NaN        Yarra  -37.80780
# 40     NaN       NaN           NaN        NaN          NaN        NaN
# 41     1.0       0.0           NaN        NaN        Yarra  -37.79940
# 42     NaN       NaN           NaN        NaN          NaN  -37.79720
# 43     2.0     147.0          18.0        NaN        Yarra  -37.80500
# 49     NaN       NaN           NaN        NaN          NaN        NaN
# 51     NaN       NaN           NaN        NaN          NaN        NaN
# 59     NaN       NaN           NaN        NaN          NaN        NaN
# 60     NaN       NaN           NaN        NaN          NaN        NaN
# ...    ...       ...           ...        ...          ...        ...
# 18366  NaN       NaN           NaN        NaN          NaN        NaN
# 18367  1.0       NaN           1.0     1977.0          NaN  -37.84740
# 18368  2.0       NaN           NaN        NaN          NaN  -37.84668
# 18369  1.0       NaN          86.0     2004.0          NaN  -37.70501
# 18370  1.0     607.0         102.0     1970.0          NaN  -37.69423
# 18371  1.0       NaN         109.0     1975.0          NaN  -37.70811
# 18372  2.0     791.0           NaN        NaN          NaN  -37.84467
# 18373  2.0       NaN         152.0     2009.0          NaN  -37.84780
# 18374  2.0       NaN         190.0     1980.0          NaN  -37.85928
# 18375  2.0     986.0           NaN        NaN          NaN  -37.84679
# 18376  3.0     696.0           NaN        NaN          NaN  -37.73501
# 18377  2.0     704.0         200.0     1981.0          NaN  -37.85639
# 18378  2.0     551.0           NaN        NaN          NaN  -37.87608
# 18379  2.0     674.0           NaN        NaN          NaN  -37.88360
# 18380  2.0     717.0         191.0     1980.0          NaN  -37.86887
# 18381  1.0       NaN          83.0     2010.0          NaN  -37.71500
# 18382  1.0     210.0          79.0     2006.0          NaN  -37.70657
# 18383  NaN       NaN           NaN        NaN          NaN        NaN
# 18384  1.0     662.0         172.0     1980.0          NaN  -37.89327
# 18385  1.0       NaN         135.0     2012.0          NaN  -37.80968
# 18386  2.0     256.0           NaN        NaN          NaN  -37.67917
# 18387  0.0       NaN           NaN        NaN          NaN  -37.68006
# 18388  2.0     652.0           NaN     1981.0          NaN  -37.90562
# 18389  2.0     333.0         133.0     1995.0          NaN  -37.85927
# 18390  4.0     436.0           NaN     1997.0          NaN  -37.85274
# 18391  1.0       NaN          89.0     2010.0          NaN  -37.86393
# 18392  5.0     866.0         157.0     1920.0          NaN  -37.85908
# 18393  2.0       NaN           NaN        NaN          NaN  -37.72006
# 18394  1.0     362.0         112.0     1920.0          NaN  -37.81188
# 18395  2.0       NaN         139.0     1950.0          NaN  -37.81829
#
#       Longtitude                  Regionname  Propertycount
# 0      144.99840       Northern Metropolitan         4019.0
# 3      144.99690       Northern Metropolitan         4019.0
# 5      144.99530       Northern Metropolitan         4019.0
# 8            NaN       Northern Metropolitan         4019.0
# 9            NaN       Northern Metropolitan         4019.0
# 10     144.99730       Northern Metropolitan         4019.0
# 12           NaN       Northern Metropolitan         4019.0
# 13           NaN       Northern Metropolitan         4019.0
# 14           NaN       Northern Metropolitan         4019.0
# 15     145.00670       Northern Metropolitan         4019.0
# 18     144.99420       Northern Metropolitan         4019.0
# 19           NaN       Northern Metropolitan         4019.0
# 20     144.99730       Northern Metropolitan         4019.0
# 21     144.99880       Northern Metropolitan         4019.0
# 24           NaN       Northern Metropolitan         4019.0
# 26     144.99750       Northern Metropolitan         4019.0
# 29     144.99590       Northern Metropolitan         4019.0
# 30     144.99650       Northern Metropolitan         4019.0
# 34           NaN       Northern Metropolitan         4019.0
# 35           NaN       Northern Metropolitan         4019.0
# 36     144.99880       Northern Metropolitan         4019.0
# 38     144.99650       Northern Metropolitan         4019.0
# 40           NaN       Northern Metropolitan         4019.0
# 41     144.99650       Northern Metropolitan         4019.0
# 42     144.99690       Northern Metropolitan         4019.0
# 43     144.99430       Northern Metropolitan         4019.0
# 49           NaN       Northern Metropolitan         4019.0
# 51           NaN       Northern Metropolitan         4019.0
# 59           NaN        Western Metropolitan         3464.0
# 60           NaN        Western Metropolitan         3464.0
# ...          ...                         ...            ...
# 18366        NaN       Southern Metropolitan         7217.0
# 18367  145.01247       Southern Metropolitan         7217.0
# 18368  144.71607        Western Metropolitan         5811.0
# 18369  144.88182        Western Metropolitan         3296.0
# 18370  144.88002        Western Metropolitan         3296.0
# 18371  144.88089        Western Metropolitan         3296.0
# 18372  145.19276        Eastern Metropolitan         4181.0
# 18373  145.18855        Eastern Metropolitan         4280.0
# 18374  145.18715        Eastern Metropolitan         4280.0
# 18375  145.20051        Eastern Metropolitan         4280.0
# 18376  145.08341        Eastern Metropolitan         2698.0
# 18377  145.23536        Eastern Metropolitan         5424.0
# 18378  145.22390        Eastern Metropolitan         7082.0
# 18379  145.22805        Eastern Metropolitan         7082.0
# 18380  145.22116        Eastern Metropolitan         7082.0
# 18381  145.07649       Northern Metropolitan         2329.0
# 18382  145.07878       Northern Metropolitan         2329.0
# 18383        NaN        Western Metropolitan        16166.0
# 18384  144.64789        Western Metropolitan        16166.0
# 18385  144.86819        Western Metropolitan         5058.0
# 18386  144.89390       Northern Metropolitan         2474.0
# 18387  144.87550       Northern Metropolitan         2474.0
# 18388  145.16761  South-Eastern Metropolitan         7392.0
# 18389  144.87904        Western Metropolitan         6380.0
# 18390  144.88738        Western Metropolitan         6380.0
# 18391  144.90484        Western Metropolitan         6380.0
# 18392  144.89299        Western Metropolitan         6380.0
# 18393  145.10547       Northern Metropolitan         1369.0
# 18394  144.88449        Western Metropolitan         6543.0
# 18395  144.87404        Western Metropolitan         6543.0
#
# [12200 rows x 22 columns]

# %%
melbourne_data = melbourne_data.fillna(melbourne_data.mean())

# %%
melbourne_data.shape
# Out:
# (18396, 22)

# %%
melbourne_data.head()
# Out:
#    Unnamed: 0      Suburb           Address  Rooms Type      Price Method  \
# 0           1  Abbotsford      85 Turner St      2    h  1480000.0      S
# 1           2  Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2           4  Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3           5  Abbotsford  40 Federation La      3    h   850000.0     PI
# 4           6  Abbotsford       55a Park St      4    h  1600000.0     VB
#
#   SellerG       Date  Distance      ...        Bathroom  Car  Landsize  \
# 0  Biggin  3/12/2016       2.5      ...             1.0  1.0     202.0
# 1  Biggin  4/02/2016       2.5      ...             1.0  0.0     156.0
# 2  Biggin  4/03/2017       2.5      ...             2.0  0.0     134.0
# 3  Biggin  4/03/2017       2.5      ...             2.0  1.0      94.0
# 4  Nelson  4/06/2016       2.5      ...             1.0  2.0     120.0
#
#    BuildingArea    YearBuilt  CouncilArea  Lattitude Longtitude  \
# 0    151.220219  1965.879996        Yarra   -37.7996   144.9984
# 1     79.000000  1900.000000        Yarra   -37.8079   144.9934
# 2    150.000000  1900.000000        Yarra   -37.8093   144.9944
# 3    151.220219  1965.879996        Yarra   -37.7969   144.9969
# 4    142.000000  2014.000000        Yarra   -37.8072   144.9941
#
#               Regionname  Propertycount
# 0  Northern Metropolitan         4019.0
# 1  Northern Metropolitan         4019.0
# 2  Northern Metropolitan         4019.0
# 3  Northern Metropolitan         4019.0
# 4  Northern Metropolitan         4019.0
#
# [5 rows x 22 columns]

# %%
melbourne_data.describe()
# Out:
#          Unnamed: 0         Rooms         Price      Distance      Postcode  \
# count  18396.000000  18396.000000  1.839600e+04  18396.000000  18396.000000
# mean   11826.787073      2.935040  1.056697e+06     10.389986   3107.140147
# std     6800.710448      0.958202  6.419217e+05      6.008886     94.998413
# min        1.000000      1.000000  8.500000e+04      0.000000   3000.000000
# 25%     5936.750000      2.000000  6.330000e+05      6.300000   3046.000000
# 50%    11820.500000      3.000000  8.800000e+05      9.700000   3085.000000
# 75%    17734.250000      3.000000  1.302000e+06     13.300000   3149.000000
# max    23546.000000     12.000000  9.000000e+06     48.100000   3978.000000
#
#            Bedroom2      Bathroom           Car       Landsize  BuildingArea  \
# count  18396.000000  18396.000000  18396.000000   18396.000000  18396.000000
# mean       2.913043      1.538492      1.615520     558.116371    151.220219
# std        0.868936      0.620880      0.857984    3428.730081    337.236125
# min        0.000000      0.000000      0.000000       0.000000      0.000000
# 25%        2.000000      1.000000      1.000000     250.750000    140.000000
# 50%        3.000000      1.538492      1.615520     558.116371    151.220219
# 75%        3.000000      2.000000      2.000000     596.000000    151.220219
# max       20.000000      8.000000     10.000000  433014.000000  44515.000000
#
#           YearBuilt     Lattitude    Longtitude  Propertycount
# count  18396.000000  18396.000000  18396.000000   18396.000000
# mean    1965.879996    -37.809849    144.996338    7517.975265
# std       25.827879      0.073436      0.096260    4488.294596
# min     1196.000000    -38.182550    144.431810     249.000000
# 25%     1965.879996    -37.845400    144.950952    4294.000000
# 50%     1965.879996    -37.809849    144.996338    6567.000000
# 75%     1970.000000    -37.767400    145.046900   10331.000000
# max     2018.000000    -37.408530    145.526350   21650.000000

# %% [markdown]
# ## Selecting and Filtering Data

# %%
melbourne_data.columns
# Out:
# Index(['Unnamed: 0', 'Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method',
#        'SellerG', 'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom',
#        'Car', 'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea',
#        'Lattitude', 'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %% [markdown]
# ### Selecting a Single Column

# %%
melbourne_data.Price.head()
# Out:
# 0    1480000.0
# 1    1035000.0
# 2    1465000.0
# 3     850000.0
# 4    1600000.0
# Name: Price, dtype: float64

# %% [markdown]
# ### Selecting Multiple Columns

# %%
column_of_interest = ['Landsize','BuildingArea']
two_columns_of_data = melbourne_data[column_of_interest]

# %%
two_columns_of_data.describe()
# Out:
#             Landsize  BuildingArea
# count   18396.000000  18396.000000
# mean      558.116371    151.220219
# std      3428.730081    337.236125
# min         0.000000      0.000000
# 25%       250.750000    140.000000
# 50%       558.116371    151.220219
# 75%       596.000000    151.220219
# max    433014.000000  44515.000000

# %% [markdown]
# ## First Scikit-learn Model

# %% [markdown]
# ### Choosing the Prediction Target

# %%
y = melbourne_data.Price

# %% [markdown]
# ### Chosing Predictors

# %%
melbourne_predictors = ['Rooms', 'Bathroom', 'Landsize', 'BuildingArea', 
                        'YearBuilt', 'Lattitude', 'Longtitude']

# %%
X = melbourne_data[melbourne_predictors]

# %% [markdown]
# ### Building Your Model

# %%
from sklearn.tree import DecisionTreeRegressor

#Define model

melbourne_model = DecisionTreeRegressor()

# Fit model
melbourne_model.fit(X,y)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')

# %%
print("Making predictions for the following 5 houses:")
print(X.head())
print("The predictions are")
print(melbourne_model.predict(X.head()))
# Out:
# Making predictions for the following 5 houses:
#    Rooms  Bathroom  Landsize  BuildingArea    YearBuilt  Lattitude  Longtitude
# 0      2       1.0     202.0    151.220219  1965.879996   -37.7996    144.9984
# 1      2       1.0     156.0     79.000000  1900.000000   -37.8079    144.9934
# 2      3       2.0     134.0    150.000000  1900.000000   -37.8093    144.9944
# 3      3       2.0      94.0    151.220219  1965.879996   -37.7969    144.9969
# 4      4       1.0     120.0    142.000000  2014.000000   -37.8072    144.9941
# The predictions are
# [ 1480000.  1035000.  1465000.   850000.  1600000.]

# %% [markdown]
# ## Model Validation

# %%
from sklearn.metrics import mean_absolute_error

predicted_home_prices = melbourne_model.predict(X)
mean_absolute_error(y, predicted_home_prices)
# Out:
# 65102.271909457879

# %%
from sklearn.model_selection import train_test_split

# split data into training and validation data, for both predictors and target
# The split is based on a random number generator. Supplying a numeric value to
# the random_state argument guarantees we get the same split every time we
# run this script.

train_X, val_X, train_y, val_y = train_test_split(X, y, random_state = 0)

#Define model
melbourne_model = DecisionTreeRegressor()

#Fit model
melbourne_model.fit(train_X, train_y)

#get predicted prices on validation data
val_predictions = melbourne_model.predict(val_X)
print(mean_absolute_error(val_y, val_predictions))
# Out:
# 271069.212842

# %% [markdown]
# ## Underfitting, Overfitting and Model optimization

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.tree import DecisionTreeRegressor

## max_leaf_nodes argument provides a very sensible way to control overfitting vs underfitting

def get_mea(max_leaf_nodes, predictors_train, predictors_val, targ_train, targ_val):
    model = DecisionTreeRegressor(max_leaf_nodes=max_leaf_nodes, random_state=0)
    model.fit(predictors_train, targ_train)
    preds_val = model.predict(predictors_val)
    mae = mean_absolute_error(targ_val, preds_val)
    return(mae)

# %%
#compare MAE with differing values of max_leaf_nodes

for max_leaf_nodes in [5, 50, 500, 5000]:
    my_mae = get_mea(max_leaf_nodes, train_X, val_X, train_y, val_y)
    print('Max leaf nodes: %d  \t\t Mean Absolute Error: %d ' %(max_leaf_nodes, my_mae))
    ## % They are used for formatting strings. %s acts a placeholder for a string 
    ## while %d acts as a placeholder for a number. 
    ##Their associated values are passed in via a tuple using the % operator.
# Out:
# Max leaf nodes: 5  		 Mean Absolute Error: 376610
# Max leaf nodes: 50  		 Mean Absolute Error: 280628
# Max leaf nodes: 500  		 Mean Absolute Error: 257667
# Max leaf nodes: 5000  		 Mean Absolute Error: 269649

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

forest_model = RandomForestRegressor()
forest_model.fit(train_X, train_y)
melb_preds = forest_model.predict(val_X)
print(mean_absolute_error(val_y, melb_preds))
# Out:
# 225842.724347
